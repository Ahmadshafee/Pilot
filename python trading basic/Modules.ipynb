# %%
import pandas as pd

# %%
infy=pd.read_csv('data1.csv')
infy.head(10)
# Out:
#          Date   Open   High    Low  Close  Volume
# 0  01/31/2023  31.22  32.46  31.22  32.42  89,283
# 1  01/30/2023  31.14  31.35  30.68  31.10  63,426
# 2  01/27/2023  31.41  31.67  31.19  31.29  39,754
# 3  01/26/2023  31.00  31.53  30.70  31.49  48,032
# 4  01/25/2023  30.70  30.85  30.34  30.85  47,721
# 5  01/24/2023  31.73  31.73  30.71  30.85  98,668
# 6  01/23/2023  30.72  31.23  30.37  30.65  68,057
# 7  01/20/2023  30.61  30.77  30.11  30.57  63,509
# 8  01/19/2023  29.76  30.48  29.51  30.37  52,384
# 9  01/18/2023  30.76  30.90  30.06  30.11  53,969

# %%
infy_close = infy[['Date','Close']]
infy_close.set_index('Date',inplace=True)
infy_close.head(10)
# Out:
#             Close
# Date
# 01/31/2023  32.42
# 01/30/2023  31.10
# 01/27/2023  31.29
# 01/26/2023  31.49
# 01/25/2023  30.85
# 01/24/2023  30.85
# 01/23/2023  30.65
# 01/20/2023  30.57
# 01/19/2023  30.37
# 01/18/2023  30.11

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
plt.figure(figsize =(24,5))
plt.plot(infy_close,'b')
plt.plot(infy_close,'ro')
plt.grid(True)
plt.title('Infosys Close Price Representation')
plt.xlabel('day')
plt.ylabel('Close day')
plt.plot(infy_close)
plt.show()

# %%
infy2=pd.read_csv('data1.csv')
infy.head(8)
# Out:
#          Date   Open   High    Low  Close  Volume
# 0  01/31/2023  31.22  32.46  31.22  32.42  89,283
# 1  01/30/2023  31.14  31.35  30.68  31.10  63,426
# 2  01/27/2023  31.41  31.67  31.19  31.29  39,754
# 3  01/26/2023  31.00  31.53  30.70  31.49  48,032
# 4  01/25/2023  30.70  30.85  30.34  30.85  47,721
# 5  01/24/2023  31.73  31.73  30.71  30.85  98,668
# 6  01/23/2023  30.72  31.23  30.37  30.65  68,057
# 7  01/20/2023  30.61  30.77  30.11  30.57  63,509

# %%
infy2_close=infy[['Date','Open','Close']]
infy2_close.set_index('Date',inplace=True)
infy2_1=infy2_close.head(8)
infy2_1
# Out:
#              Open  Close
# Date
# 01/31/2023  31.22  32.42
# 01/30/2023  31.14  31.10
# 01/27/2023  31.41  31.29
# 01/26/2023  31.00  31.49
# 01/25/2023  30.70  30.85
# 01/24/2023  31.73  30.85
# 01/23/2023  30.72  30.65
# 01/20/2023  30.61  30.57

# %%
plt.figure(figsize=(15,5))
plt.plot(infy2_1,'ro')
plt.grid(True)
plt.plot(infy2_1)

# %%
import numpy as np
stock_values = [123.1,125.5,176.4,180,190.5,235.4,256,286.09]
sv=np.array(stock_values)
print(stock_values)
type(sv)
# Out:
# [123.1, 125.5, 176.4, 180, 190.5, 235.4, 256, 286.09]
# numpy.ndarray
